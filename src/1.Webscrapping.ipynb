# %%
import requests
from bs4 import BeautifulSoup
import csv

# List of URLs to scrape
urls = [
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/plus/1?saison_id=2019&wettbewerb_id=&day=&heim_gast=&punkte=&datum_von=&datum_bis=", # zurich 19-20
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/plus/1?saison_id=2020&wettbewerb_id=&day=&heim_gast=&punkte=&datum_von=&datum_bis=", # 20-21
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/plus/1?saison_id=2021&wettbewerb_id=&day=&heim_gast=&punkte=&datum_von=&datum_bis=", # 21-22
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/plus/1?saison_id=2022&wettbewerb_id=&day=&heim_gast=&punkte=&datum_von=&datum_bis=", # 22-23
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/plus/1?saison_id=2023&wettbewerb_id=&day=&heim_gast=&punkte=&datum_von=&datum_bis=", # 23-24
    "https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/plus/1?saison_id=2024&wettbewerb_id=&day=&heim_gast=&punkte=&datum_von=&datum_bis=", # 24-25
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # lausanne 19-20
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-lausanne-sport/spielplandatum/verein/527/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",# 24-25
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # Geneve 19-20
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/servette-fc/spielplandatum/verein/61/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # BSC Young Boys 19-20
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/bsc-young-boys/spielplandatum/verein/452/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/fc-lugano/spielplandatum/verein/2790/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 FC Lugano
    "https://www.transfermarkt.com/fc-lugano/spielplandatum/verein/2790/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-lugano/spielplandatum/verein/2790/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-lugano/spielplandatum/verein/2790/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-lugano/spielplandatum/verein/2790/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-lugano/spielplandatum/verein/2790/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/fc-st-gallen-1879/spielplandatum/verein/257/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 FC St.Gallen
    "https://www.transfermarkt.com/fc-st-gallen-1879/spielplandatum/verein/257/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-st-gallen-1879/spielplandatum/verein/257/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-st-gallen-1879/spielplandatum/verein/257/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-st-gallen-1879/spielplandatum/verein/257/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-st-gallen-1879/spielplandatum/verein/257/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/fc-winterthur/spielplandatum/verein/242/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Winterthur
    "https://www.transfermarkt.com/fc-winterthur/spielplandatum/verein/242/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-winterthur/spielplandatum/verein/242/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-winterthur/spielplandatum/verein/242/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-winterthur/spielplandatum/verein/242/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-winterthur/spielplandatum/verein/242/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/fc-luzern/spielplandatum/verein/434/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Luzern
    "https://www.transfermarkt.com/fc-luzern/spielplandatum/verein/434/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-luzern/spielplandatum/verein/434/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-luzern/spielplandatum/verein/434/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-luzern/spielplandatum/verein/434/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-luzern/spielplandatum/verein/434/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/fc-basel-1893/spielplandatum/verein/26/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Basel
    "https://www.transfermarkt.com/fc-basel-1893/spielplandatum/verein/26/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-basel-1893/spielplandatum/verein/26/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-basel-1893/spielplandatum/verein/26/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-basel-1893/spielplandatum/verein/26/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-basel-1893/spielplandatum/verein/26/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/fc-sion/spielplandatum/verein/321/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Sion
    "https://www.transfermarkt.com/fc-sion/spielplandatum/verein/321/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/fc-sion/spielplandatum/verein/321/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/fc-sion/spielplandatum/verein/321/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/fc-sion/spielplandatum/verein/321/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/fc-sion/spielplandatum/verein/321/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/yverdon-sport-fc/spielplandatum/verein/322/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Yverdon
    "https://www.transfermarkt.com/yverdon-sport-fc/spielplandatum/verein/322/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/yverdon-sport-fc/spielplandatum/verein/322/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/yverdon-sport-fc/spielplandatum/verein/322/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/yverdon-sport-fc/spielplandatum/verein/322/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/yverdon-sport-fc/spielplandatum/verein/322/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
    "https://www.transfermarkt.com/grasshopper-club-zurich/spielplandatum/verein/504/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Grasshoper club Zurich
    "https://www.transfermarkt.com/grasshopper-club-zurich/spielplandatum/verein/504/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
    "https://www.transfermarkt.com/grasshopper-club-zurich/spielplandatum/verein/504/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
    "https://www.transfermarkt.com/grasshopper-club-zurich/spielplandatum/verein/504/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
    "https://www.transfermarkt.com/grasshopper-club-zurich/spielplandatum/verein/504/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
    "https://www.transfermarkt.com/grasshopper-club-zurich/spielplandatum/verein/504/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25
]

# Headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# CSV file columns
columns = ["Competition", "Matchday", "Date", "Time", "Home Team", "Ranking Home Team", "Away Team", "Ranking Away Team", "Attendance", "Result"]

# Create a list to store all extracted data
all_data = []

# Loop through each URL
for url in urls:
    print(f"Scraping: {url}")
    # Send a GET request
    response = requests.get(url, headers=headers)
    # Parse the HTML content
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the table within the responsive-table div
    table = soup.find("div", class_="responsive-table").find("table")
    # Extract all rows from tbody
    rows = table.find("tbody").find_all("tr")

    # Initialize a variable to hold the current competition name
    current_competition = ""

    # Loop through each row
    for row in rows:
        # Check if the row contains a competition name
        competition_cell = row.find("td", class_="extrarow bg_blau_20 hauptlink")
        if competition_cell:
            # Update the current competition name
            current_competition = competition_cell.get_text(strip=True)
            continue  # Skip to the next row since this row doesn't contain match data

        cells = row.find_all("td")  # Extract all cells within the row
        if len(cells) >= 11:  # Ensure the row contains enough data columns
            matchday = cells[0].get_text(strip=True)  # First column: Matchday
            date = cells[1].get_text(strip=True)      # Second column: Date
            time = cells[2].get_text(strip=True)      # Third column: Time

            # Extract home team and its ranking
            home_team_cell = cells[4]
            home_team = home_team_cell.find("a").get_text(strip=True)  # Extract team name
            home_ranking_span = home_team_cell.find("span", class_="tabellenplatz")
            home_ranking = home_ranking_span.get_text(strip=True) if home_ranking_span else ""  # Extract ranking

            # Extract away team and its ranking
            away_team_cell = cells[6]
            away_team = away_team_cell.find("a").get_text(strip=True)  # Extract team name
            away_ranking_span = away_team_cell.find("span", class_="tabellenplatz")
            away_ranking = away_ranking_span.get_text(strip=True) if away_ranking_span else ""  # Extract ranking

            attendance = cells[9].get_text(strip=True)  # Attendance
            result = cells[10].get_text(strip=True)     # Result

            # Append the row data to the list
            all_data.append([current_competition, matchday, date, time, home_team, home_ranking, away_team, away_ranking, attendance, result])

# Write the data to a CSV file
csv_file = "transfermarkt_data_with_competitions.csv"
with open(csv_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(columns)  # Write the header
    writer.writerows(all_data)  # Write all rows

print(f"Data successfully written to {csv_file}")
# Out:
# Scraping: https://www.transfermarkt.com/fc-zurich/spielplandatum/verein/260/plus/1?saison_id=2019&wettbewerb_id=&day=&heim_gast=&punkte=&datum_von=&datum_bis=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4066106519.py in <cell line: 0>()
#      94     print(f"Scraping: {url}")
#      95     # Send a GET request
# ---> 96     response = requests.get(url, headers=headers)
#      97     # Parse the HTML content
#      98     soup = BeautifulSoup(response.content, "html.parser")
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import csv

# List of URLs to scrape
urls = [
 # Club Brugge KV
"https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Club Brugge
"https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
"https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
"https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
"https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
"https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25

# KRC Genk
"https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Genk
"https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
"https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
"https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
"https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
"https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25

# RSC Anderlecht
"https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 19-20 Anderlecht
"https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 20-21
"https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 21-22
"https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 22-23
"https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 23-24
"https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 24-25

# Union Saint-Gilloise
"https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Union SG
"https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
"https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
"https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
"https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
"https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25

# KAA Gent
"https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 19-20 Gent
"https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 20-21
"https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 21-22
"https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 22-23
"https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 23-24
"https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 24-25

# Royal Antwerp FC
"https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Royal Antwerp
"https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
"https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
"https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
"https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
"https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25

# KVC Westerlo
"https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 19-20 Westerlo
"https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 20-21
"https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 21-22
"https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 22-23
"https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 23-24
"https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 24-25

# Standard Liège
"https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 Standard Liège
"https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
"https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
"https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
"https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
"https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25

# Cercle Brugge
"https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 19-20 Cercle Brugge
"https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 20-21
"https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 21-22
"https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 22-23
"https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 23-24
"https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 24-25

# KV Mechelen
"https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",      # 19-20 Mechelen
"https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",      # 20-21
"https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",      # 21-22
"https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",      # 22-23
"https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",      # 23-24
"https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",      # 24-25

# Royal Charleroi SC
"https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 19-20 Charleroi
"https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 20-21
"https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 21-22
"https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 22-23
"https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 23-24
"https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 24-25

# Oud-Heverlee Leuven
"https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 19-20 OH Leuven
"https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 20-21
"https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 21-22
"https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 22-23
"https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 23-24
"https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",  # 24-25

# Sint-Truidense VV:contentReference[oaicite:2]{index=2}
"https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 19-20 Sint-Truiden
"https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 20-21
"https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 21-22
"https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 22-23
"https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 23-24
"https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",    # 24-25

# FCV Dender EH
"https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 19-20 Dender EH
"https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 20-21
"https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 21-22
"https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 22-23
"https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 23-24
"https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 24-25

# Zulte Waregem:contentReference[oaicite:3]{index=3}
"https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 19-20 Zulte Waregem
"https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 20-21
"https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 21-22
"https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 22-23
"https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 23-24
"https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",     # 24-25

# RAAL La Louvière:contentReference[oaicite:4]{index=4}
"https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 19-20 RAAL La Louvière
"https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 20-21
"https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 21-22
"https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 22-23
"https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 23-24
"https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1",   # 24-25

]

# Headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# CSV file columns
columns = ["Competition", "Matchday", "Date", "Time", "Home Team", "Ranking Home Team", "Away Team", "Ranking Away Team", "Attendance", "Result"]

# Create a list to store all extracted data
all_data = []

# Loop through each URL
for url in urls:
    print(f"Scraping: {url}")
    # Send a GET request
    response = requests.get(url, headers=headers)
    # Parse the HTML content
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the table within the responsive-table div
    table = soup.find("div", class_="responsive-table").find("table")
    # Extract all rows from tbody
    rows = table.find("tbody").find_all("tr")

    # Initialize a variable to hold the current competition name
    current_competition = ""

    # Loop through each row
    for row in rows:
        # Check if the row contains a competition name
        competition_cell = row.find("td", class_="extrarow bg_blau_20 hauptlink")
        if competition_cell:
            # Update the current competition name
            current_competition = competition_cell.get_text(strip=True)
            continue  # Skip to the next row since this row doesn't contain match data

        cells = row.find_all("td")  # Extract all cells within the row
        if len(cells) >= 11:  # Ensure the row contains enough data columns
            matchday = cells[0].get_text(strip=True)  # First column: Matchday
            date = cells[1].get_text(strip=True)      # Second column: Date
            time = cells[2].get_text(strip=True)      # Third column: Time

            # Extract home team and its ranking
            home_team_cell = cells[4]
            home_team = home_team_cell.find("a").get_text(strip=True)  # Extract team name
            home_ranking_span = home_team_cell.find("span", class_="tabellenplatz")
            home_ranking = home_ranking_span.get_text(strip=True) if home_ranking_span else ""  # Extract ranking

            # Extract away team and its ranking
            away_team_cell = cells[6]
            away_team = away_team_cell.find("a").get_text(strip=True)  # Extract team name
            away_ranking_span = away_team_cell.find("span", class_="tabellenplatz")
            away_ranking = away_ranking_span.get_text(strip=True) if away_ranking_span else ""  # Extract ranking

            attendance = cells[9].get_text(strip=True)  # Attendance
            result = cells[10].get_text(strip=True)     # Result

            # Append the row data to the list
            all_data.append([current_competition, matchday, date, time, home_team, home_ranking, away_team, away_ranking, attendance, result])

# Write the data to a CSV file
csv_file = "RawDataB.csv"
with open(csv_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(columns)  # Write the header
    writer.writerows(all_data)  # Write all rows

print(f"Data successfully written to {csv_file}")
# Out:
# Scraping: https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/club-brugge-kv/spielplandatum/verein/2282/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/krc-genk/spielplandatum/verein/1184/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/rsc-anderlecht/spielplandatum/verein/58/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royale-union-saint-gilloise/spielplandatum/verein/3948/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kaa-gent/spielplandatum/verein/157/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-antwerp-fc/spielplandatum/verein/1096/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kvc-westerlo/spielplandatum/verein/968/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/standard-liege/spielplandatum/verein/3057/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/cercle-brugge/spielplandatum/verein/520/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/kv-mechelen/spielplandatum/verein/354/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/royal-charleroi-sc/spielplandatum/verein/172/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/oud-heverlee-leuven/spielplandatum/verein/2727/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/sint-truidense-vv/spielplandatum/verein/475/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/fcv-dender-eh/spielplandatum/verein/9010/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/zulte-waregem/spielplandatum/verein/3508/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2019/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2020/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2021/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2022/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2023/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Scraping: https://www.transfermarkt.com/raal-la-louviere/spielplandatum/verein/3901/saison_id/2024/wettbewerb_id//datum_von/0000-00-00/datum_bis/0000-00-00/day/0/plus/1
# Data successfully written to transfermarkt_data_with_competitions.csv

# %%
# Google Colab file download removed - file saved locally

# %%
# Google Colab mounting removed
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Google Colab file download removed - file saved locally
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_first_200.csv for rows 0 to 200.

# %%
# Google Colab file download removed - file saved locally
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_200_399.csv for rows 200 to 399.

# %%
# Google Colab file download removed - file saved locally
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_400_599.csv for rows 400 to 599.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_600_799.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 600
end_row = 800

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 600 to 799.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_600_799.csv for rows 600 to 799.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_800_999.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 800
end_row = 1000

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 800 to 999.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_800_999.csv for rows 800 to 999.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1000_1199.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 1000
end_row = 1200

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 1000 to 1199.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1000_1199.csv for rows 1000 to 1199.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1200_1399.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 1200
end_row = 1400

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 1200 to 1399.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1200_1399.csv for rows 1200 to 1399.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1400_1599.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 1400
end_row = 1600

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 1400 to 1599.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1400_1599.csv for rows 1400 to 1599.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1600_1799.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 1600
end_row = 1800

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 1600 to 1799.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1600_1799.csv for rows 1600 to 1799.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1800_1999.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 1800
end_row = 2000

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 1800 to 1999.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1800_1999.csv for rows 1800 to 1999.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2000_2199.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 2000
end_row = 2200

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 2000 to 2199.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2000_2199.csv for rows 2000 to 2199.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2200_2399.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 2200
end_row = 2400

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 2200 to 2399.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2200_2399.csv for rows 2200 to 2399.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2400_2599.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 2400
end_row = 2600

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 2400 to 2599.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2400_2599.csv for rows 2400 to 2599.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2600_2799.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 2600
end_row = 2800

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 2600 to 2799.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2600_2799.csv for rows 2600 to 2799.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2800_2999.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 2800
end_row = 3000

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 2800 to 2999.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2800_2999.csv for rows 2800 to 2999.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3000_3199.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 3000
end_row = 3200

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 3000 to 3199.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3000_3199.csv for rows 3000 to 3199.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3200_3399.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 3200
end_row = 3400

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 3200 to 3399.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3200_3399.csv for rows 3200 to 3399.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3400_3599.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 3400
end_row = 3600

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 3400 to 3599.")
# Out:
# Error parsing date/time for row: date='Unknown', time='Unknown' - time data 'Unknown Unknown' does not match format '%a %d/%m/%y %I:%M %p'
# Error parsing date/time for row: date='Unknown', time='Unknown' - time data 'Unknown Unknown' does not match format '%a %d/%m/%y %I:%M %p'
# Error parsing date/time for row: date='Unknown', time='Unknown' - time data 'Unknown Unknown' does not match format '%a %d/%m/%y %I:%M %p'
# Error parsing date/time for row: date='Unknown', time='Unknown' - time data 'Unknown Unknown' does not match format '%a %d/%m/%y %I:%M %p'
# Error parsing date/time for row: date='Unknown', time='Unknown' - time data 'Unknown Unknown' does not match format '%a %d/%m/%y %I:%M %p'
# Error parsing date/time for row: date='Unknown', time='Unknown' - time data 'Unknown Unknown' does not match format '%a %d/%m/%y %I:%M %p'
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3400_3599.csv for rows 3400 to 3599.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3600_3799.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 3600
end_row = 3800

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 3600 to 3799.")
# Out:
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3600_3799.csv for rows 3600 to 3799.

# %%
import csv
import requests
from datetime import datetime
from google.colab import files
import os
import time

# Dictionary mapping club names to their coordinates
club_coordinates = {
    "Club Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Cercle Brugge": {"lat": 51.19333, "lon": 3.18056},
    "Genk": {"lat": 51.00500, "lon": 5.53333},
    "RSC Anderlecht": {"lat": 50.83417, "lon": 4.29833},
    "Union SG": {"lat": 50.81733, "lon": 4.32417},
    "KAA Gent": {"lat": 51.01611, "lon": 3.73417},
    "Royal Antwerp": {"lat": 51.22500, "lon": 4.46992},
    "KVC Westerlo": {"lat": 51.09482, "lon": 4.92881},
    "Standard Liège": {"lat": 50.60597, "lon": 5.53934},
    "KV Mechelen": {"lat": 51.03718, "lon": 4.48640},
    "R Charleroi SC": {"lat": 50.41461, "lon": 4.45379},
    "OH Leuven": {"lat": 50.86833, "lon": 4.69417},
    "Sint-Truiden": {"lat": 50.81347, "lon": 5.16626},
    "FCV Dender EH": {"lat": 50.88368, "lon": 4.07118},
    "Zulte Waregem": {"lat": 50.88306, "lon": 3.42889},
    "La Louvière": {"lat": 50.47750, "lon": 4.20131}
}

# Function to fetch weather data using Open Meteo Historical API

def get_weather_open_meteo(date, time, home_team):
    try:
        # Get coordinates for the home team
        coordinates = club_coordinates.get(home_team)
        if not coordinates:
            return "None", "None"  # Fallback if the team is not in the dictionary

        lat = coordinates["lat"]
        lon = coordinates["lon"]

        # Format date to YYYY-MM-DD and extract hour
        try:
            dt_object = datetime.strptime(f"{date} {time}", "%a %d/%m/%y %I:%M %p")
            formatted_date = dt_object.strftime("%Y-%m-%d")
            match_hour = dt_object.hour
        except ValueError as ve:
            print(f"Error parsing date/time for row: date='{date}', time='{time}' - {ve}")
            return "None", "None"

        # Check if the match date is in the future
        current_date = datetime.now()
        if dt_object > current_date:
            return "None", "None"

        # Call Open Meteo Historical Weather API
        weather_url = f"https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": lat,
            "longitude": lon,
            "start_date": formatted_date,
            "end_date": formatted_date,
            "hourly": "temperature_2m,weathercode",
            "timezone": "Europe/Zurich"
        }

        while True:
            response = requests.get(weather_url, params=params)
            if response.status_code == 200:
                weather_data = response.json()
                hourly_data = weather_data.get("hourly", {})
                temperatures = hourly_data.get("temperature_2m", [None])
                weather_codes = hourly_data.get("weathercode", [None])

                # Adjust to ensure correct hour is within bounds of returned data
                if len(temperatures) > match_hour and len(weather_codes) > match_hour:
                    temperature = temperatures[match_hour]
                    weather_code = weather_codes[match_hour]

                    # Translate weather code to descriptive text
                    weather_description = "Unknown"
                    if weather_code is not None:
                        if weather_code in [0, 1]:
                            weather_description = "Clear or mostly clear"
                        elif weather_code in [2, 3]:
                            weather_description = "Partly cloudy"
                        elif weather_code in [45, 48]:
                            weather_description = "Foggy"
                        elif weather_code in [51, 53, 55, 56, 57]:
                            weather_description = "Drizzle"
                        elif weather_code in [61, 63, 65, 66, 67]:
                            weather_description = "Rainy"
                        elif weather_code in [71, 73, 75, 77]:
                            weather_description = "Snowy"
                        elif weather_code in [80, 81, 82]:
                            weather_description = "Showers"
                        elif weather_code in [95, 96, 99]:
                            weather_description = "Thunderstorm"

                    weather = weather_description
                else:
                    weather = "None"
                    temperature = "None"

                return weather, temperature
            elif response.status_code == 429:
                print("API request limit exceeded. Retrying in 60 seconds...")
                time.sleep(60)
            else:
                print(f"API request failed with status code {response.status_code} and response: {response.text}")
                return "None", "None"
    except Exception as e:
        print(f"Error fetching weather using Open Meteo API: {e}")
        return "None", "None"

# Read the existing CSV file
input_csv = "../Data/drive/MyDrive/CS_project/Data/RawDataB.csv"
output_csv = "../Data/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3800_3978.csv"

# Process the next 200 rows (rows 0 to 200)
start_row = 3800
end_row = 3979

with open(input_csv, mode="r", encoding="utf-8-sig") as infile:
    reader = csv.DictReader(infile)
    fieldnames = reader.fieldnames + ["Weather", "Temperature (°C)"]  # Add new columns
    rows = list(reader)

    with open(output_csv, mode="w", newline="", encoding="utf-8-sig") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        # Write the header
        writer.writeheader()

        for row in rows[start_row:end_row]:
            # Extract match details
            date = row.get("Date")
            time = row.get("Time")
            home_team = row.get("Home Team")  # Match with the club name

            if not date or not time or not home_team:
                row["Weather"] = "None"
                row["Temperature (°C)"] = "None"
            else:
                # Fetch weather data using Open Meteo API
                weather, temperature = get_weather_open_meteo(date, time, home_team)

                # Append weather data to the row
                row["Weather"] = weather
                row["Temperature (°C)"] = temperature

            # Write the updated row to the output CSV
            writer.writerow(row)

print(f"Weather data successfully added to {output_csv} for rows 3800 to 3978.")
# Out:
# Error parsing date/time for row: date='Unknown', time='Unknown' - time data 'Unknown Unknown' does not match format '%a %d/%m/%y %I:%M %p'
# Weather data successfully added to /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3800_3978.csv for rows 3800 to 3978.

# %%
# Google Colab file download removed - file saved locally
# Out:
# Found 20 CSV files to merge:
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1000_1199.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1200_1399.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1400_1599.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1600_1799.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_1800_1999.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2000_2199.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_200_399.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2200_2399.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2400_2599.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2600_2799.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_2800_2999.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3000_3199.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3200_3399.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3400_3599.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3600_3799.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_3800_3978.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_400_599.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_600_799.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_800_999.csv
#  - /content/drive/MyDrive/CS_project/Data/API_split/RawDataB_weather_first_200.csv
#
# ✅ All datasets successfully combined into /content/drive/MyDrive/CS_project/Data/RawDataB_weather.csv.
